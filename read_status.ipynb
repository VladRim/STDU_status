# %%
import pandas as pd

df = pd.read_csv('19.05.21.csv', sep=';', error_bad_lines=False)

# %%
df
# Out:
#           Краткое название                                    Полное название  \
# 0     9038/0105  Доп.офис   9038/0105  Доп.офис , г.Москва, улица Серафимо...
# 1     9038/0386  Доп.офис   9038/0386  Доп.офис , г.Москва, улица Тимирязе...
# 2     9038/0415  Доп.офис   9038/0415  Доп.офис , г.Москва, переулок Климе...
# 3     9038/0984  Доп.офис   9038/0984  Доп.офис , г.Москва, проспект Ленин...
# 4    9038/01045  Доп.офис   9038/01045  Доп.офис , г.Москва, проспект Сева...
# ..                     ...                                                ...
# 456    9038/01733 Доп.офис  9038/01733 Доп.офис , г.Москва, ул.Борисовские...
# 457    9038/01738 Доп.офис  9038/01738 Доп.офис,  г. Москва, Ореховый прое...
# 458  9038/01749  Доп.офис   9038/01749  Доп.офис , г.Москва, бульвар Орехо...
# 459    9038/01765 Доп.офис  9038/01765 Доп.офис , г.Москва, ул.Луганская, ...
# 460    9038/01859 Доп.офис  9038/01859 Доп.офис , г. Москва, ул.Паромная, ...
#
# ...
